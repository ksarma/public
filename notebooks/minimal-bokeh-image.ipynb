# %%
from PIL import Image
import urllib.request
import io
import numpy
import PIL

import bokeh
from bokeh.plotting import figure, output_file, show
bokeh.plotting.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="28a8c695-f806-46b4-bd3f-352c903d559e">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Get image

# %%
fd = urllib.request.urlopen("https://yt3.ggpht.com/-v0soe-ievYE/AAAAAAAAAAI/AAAAAAAAAAA/OixOH_h84Po/s900-c-k-no-mo-rj-c0xffffff/photo.jpg")
image_file = io.BytesIO(fd.read())
im = Image.open(image_file)

# Flip due to different origin
im_array = numpy.array(im)
im_array = numpy.flipud(im_array)
im = PIL.Image.fromarray(im_array)

# %% [markdown]
# # Display

# %%
width = im.size[0]
height = im.size[1]
    
p = figure(plot_width=int(width*0.9), plot_height=int(height*0.9), x_range=(0, width), y_range=(0, height))

p.image_rgba(image=[numpy.asarray(wm_image)], x=0, y=0, dw=width, dh=height)
mask_renderer = p.image_rgba(image=[numpy.asarray(mask)], x=0, y=0, dw=width, dh=height)

handle = show(p, notebook_handle=True)
